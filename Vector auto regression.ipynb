# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Dataset=pd.read_csv("C:/Users/arpithasn/Desktop/Dataset/AirQualityUCI.csv",parse_dates=[['Date', 'Time']])

# %%
print(Dataset.shape)
# Out:
# (9471, 16)

# %%
print(Dataset.columns)
# Out:
# Index(['Date_Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
Dataset.dtypes
# Out:
# Date_Time         object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# Unnamed: 15      float64
# Unnamed: 16      float64
# dtype: object

# %%
Dataset.head(5)
# Out:
#              Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10-03-2004 18:00:00     2.6       1360.0     150.0      11.9
# 1  10-03-2004 19:00:00     2.0       1292.0     112.0       9.4
# 2  10-03-2004 20:00:00     2.2       1402.0      88.0       9.0
# 3  10-03-2004 21:00:00     2.2       1376.0      80.0       9.2
# 4  10-03-2004 22:00:00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %%
Dataset = Dataset.drop(['Unnamed: 15', 'Unnamed: 16'], axis=1)

# %%
Dataset.head(2)
# Out:
#              Date_Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10-03-2004 18:00:00     2.6       1360.0     150.0      11.9
# 1  10-03-2004 19:00:00     2.0       1292.0     112.0       9.4
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255

# %%
Dataset.dtypes
# Out:
# Date_Time         object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %%
Dataset.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
Dataset.isnull().sum()
# Out:
# Date_Time          0
# CO(GT)           114
# PT08.S1(CO)      114
# NMHC(GT)         114
# C6H6(GT)         114
# PT08.S2(NMHC)    114
# NOx(GT)          114
# PT08.S3(NOx)     114
# NO2(GT)          114
# PT08.S4(NO2)     114
# PT08.S5(O3)      114
# T                114
# RH               114
# AH               114
# dtype: int64

# %%
Dataset.corr()
# Out:
#                  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# CO(GT)         1.000000     0.041411  0.128351 -0.031378       0.029926
# PT08.S1(CO)    0.041411     1.000000  0.170007  0.852687       0.933102
# NMHC(GT)       0.128351     0.170007  1.000000  0.037323       0.110104
# C6H6(GT)      -0.031378     0.852687  0.037323  1.000000       0.767433
# PT08.S2(NMHC)  0.029926     0.933102  0.110104  0.767433       1.000000
# NOx(GT)        0.526451     0.277993 -0.004427 -0.001174       0.331272
# PT08.S3(NOx)  -0.089981     0.087019  0.048821  0.512193      -0.073667
# NO2(GT)        0.671127     0.154030  0.103307 -0.010992       0.176488
# PT08.S4(NO2)  -0.073724     0.845149  0.162680  0.774673       0.874782
# PT08.S5(O3)    0.080310     0.892434  0.101185  0.641334       0.909905
# T             -0.068939     0.754844 -0.000009  0.971375       0.669025
# RH            -0.048227     0.745375  0.008284  0.925062       0.585803
# ...

# %%
Dataset.timestamp=Dataset.Date_Time
Dataset.index=Dataset.timestamp
Dataset.drop(['Date_Time'], axis=1, inplace=True)
Dataset.head()
# Out:
# C:\Users\arpithasn\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# Date_Time
# 10-03-2004 18:00:00     2.6       1360.0     150.0      11.9         1046.0
# 10-03-2004 19:00:00     2.0       1292.0     112.0       9.4          955.0
# 10-03-2004 20:00:00     2.2       1402.0      88.0       9.0          939.0
# 10-03-2004 21:00:00     2.2       1376.0      80.0       9.2          948.0
# 10-03-2004 22:00:00     1.6       1272.0      51.0       6.5          836.0
#
#                      NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# Date_Time
# 10-03-2004 18:00:00    166.0        1056.0    113.0        1692.0
# ...

# %%
Data=Dataset.drop(['PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)','PT08.S2(NMHC)','AH'], axis=1)
cols = Data.columns
cols
# Out:
# Index(['CO(GT)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH'],
#       dtype='object')

# %%
Data.isnull().sum()
# Out:
# CO(GT)          114
# NOx(GT)         114
# PT08.S3(NOx)    114
# NO2(GT)         114
# PT08.S4(NO2)    114
# PT08.S5(O3)     114
# T               114
# RH              114
# dtype: int64

# %%
#Missing value treatment
cols = Data.columns
for j in cols:
    for i in range(0,len(Data)):
       if Data[j][i] == -200:
           Data[j][i] = Data[j][i-1]

# %%
Data.dropna(inplace=True)

# %%
Data.isnull().sum()
# Out:
# CO(GT)          0
# NOx(GT)         0
# PT08.S3(NOx)    0
# NO2(GT)         0
# PT08.S4(NO2)    0
# PT08.S5(O3)     0
# T               0
# RH              0
# dtype: int64

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen
coint_johansen(Data,-1,1).eig
# Out:
# array([1.54412776e-01, 8.85466109e-02, 7.45029464e-02, 7.22839780e-02,
#        5.21514006e-02, 1.91909942e-02, 1.19650843e-02, 1.32514982e-04])

# %%
#Creating the train and validation set
train = Data[:int(0.8*(len(Dataset)))]
valid = Data[int(0.8*(len(Dataset))):]

# %%
print (train.shape)
print (valid.shape)
# Out:
# (7576, 8)
# (1781, 8)

# %%
from statsmodels.tsa.vector_ar.var_model import VAR

# %%
model = VAR(endog=train)
model_fit = model.fit()
# Out:
# C:\Users\arpithasn\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
prediction = model_fit.forecast(model_fit.y , steps=len(valid))

# %%
#converting predictions to dataframe
pred = pd.DataFrame(index=range(0,len(prediction)),columns=[cols])
for j in range(0,8):
    for i in range(0, len(prediction)):
       pred.iloc[i][j] = prediction[i][j]

# %%
pred
# Out:
#        CO(GT)  NOx(GT) PT08.S3(NOx)  NO2(GT) PT08.S4(NO2) PT08.S5(O3)  \
# 0      4.1771  683.695      568.388  169.369      1393.21     1464.27
# 1     4.12679  663.275      585.544  169.035      1376.02     1474.56
# 2     4.05723  643.117      602.942  168.147      1358.48     1477.09
# 3     3.97489    623.5      620.185  166.832      1341.37     1473.73
# 4     3.88487  604.627      636.981    165.2      1325.21     1465.99
# 5     3.79109  586.637      653.124  163.341      1310.37     1455.11
# 6     3.69655  569.618      668.472  161.331      1297.05     1442.09
# 7     3.60347  553.618      682.937  159.234      1285.36     1427.75
# 8     3.51347  538.653      696.472  157.099      1275.33     1412.69
# 9     3.42764  524.714      709.063  154.965      1266.92     1397.42
# 10    3.34672  511.775      720.716  152.865      1260.06     1382.28
# 11    3.27111  499.795      731.457  150.821      1254.66     1367.56
# ...

# %%
#Check rmse
import math
from sklearn.metrics import mean_squared_error
for i in cols:
    print('rmse value for', i, 'is : ', math.sqrt(mean_squared_error(pred[i], valid[i])))
# Out:
# rmse value for CO(GT) is :  1.3819097191295275
# rmse value for NOx(GT) is :  206.67988948572903
# rmse value for PT08.S3(NOx) is :  242.91879862398594
# rmse value for NO2(GT) is :  66.84629729837506
# rmse value for PT08.S4(NO2) is :  495.7981870588538
# rmse value for PT08.S5(O3) is :  442.7478899775463
# rmse value for T is :  10.930072117523727
# rmse value for RH is :  17.253967579463218

# %%
final=pred.iloc[:,0].values
final[50]
# Out:
# 2.470820151893947

# %%
print (final.shape)
# Out:
# (1781,)

# %%
for i in reversed(final):
      print(i)
# Out:
# 2.134975263085752
# 2.1349752631773438
# 2.1349752632698564
# 2.134975263363299
# 2.1349752634576804
# 2.1349752635530104
# 2.1349752636492987
# 2.134975263746556
# 2.134975263844791
# 2.134975263944014
# 2.1349752640442343
# 2.134975264145462
# 2.1349752642477062
# 2.134975264350979
# 2.1349752644552904
# 2.1349752645606506
# 2.1349752646670694
# 2.1349752647745586
# 2.134975264883128
# 2.1349752649927893
# 2.1349752651035527
# 2.13497526521543
# 2.1349752653284315
# 2.134975265442569
# 2.1349752655578547
# 2.1349752656742984
# 2.1349752657919137
# 2.1349752659107106
# 2.134975266030702
# 2.1349752661519
# 2.134975266274316
# 2.134975266397963
# 2.1349752665228534
# 2.1349752666489987
# 2.1349752667764124
# 2.1349752669051063
# 2.1349752670350948
# 2.13497526716639
# 2.134975267299005
# 2.134975267432954
# 2.134975267568249
# 2.1349752677049048
# 2.134975267842934
# 2.134975267982351
# 2.134975268123169
# 2.1349752682654026
# 2.1349752684090664
# 2.1349752685541743
# ...
